# %% [markdown]
# # Introduction

# %%
from motif import Motif
import networkx as nx

# NETWORKX GRAPH
gml1 = 'karate.gml'
g1 = nx.read_gml(gml1)

gml2 = 'adjnoun.gml'
g2 = nx.read_gml(gml2)

# %%
motif = Motif(nx_graph=g1, title='FOO')

# style = { 'layout': { 'type': 'grid' } }
# motif = Motif(nx_graph=g1, style=style)

motif.plot()

# motif.state
# Out:
# Motif(value=None, layout=Layout(height='600px', width='100%'), state={'data': [{'nodes': [{'id': '1', 'value':…

# %%
motif

# %%
motif_json = Motif(json_path='group.json', group_edges=False)
motif_json
# Out:
# Reading JSON file, all other params will be ignored...
# Motif(value=None, layout=Layout(height='600px', width='100%'), state={'data': [{'nodes': [{'create_date': '201…

# %%
# motif_csv = Motif(csv_path='test.csv')
motif_csv = Motif(csv_path='test.csv', group_edges=False)
# motif_csv = Motif(csv_path='demo.csv', group_edges=True)
motif_csv

# %%
# motif_json.add_graph(csv_path='test.csv')
motif_json.state
# Out:
# {'data': [{'nodes': [{'create_date': '2019-01-03T00:00:00',
#      'icon': 'account_balance',
#      'id': 'account_7',
#      'is_different_bank': 0,
#      'data': {},
#      'defaultStyle': {}},
#     {'create_date': '2019-01-05T00:00:00',
#      'icon': 'account_balance',
#      'id': 'account_20',
#      'is_different_bank': 0,
#      'data': {},
#      'defaultStyle': {}},
#     {'create_date': '2019-01-07T00:00:00',
#      'icon': 'account_balance',
#      'id': 'account_55',
#      'is_different_bank': 0,
#      'data': {},
#      'defaultStyle': {}},
#     {'create_date': '2019-01-15T00:00:00',
#      'icon': 'account_balance',
#      'id': 'account_81',
#      'is_different_bank': 0,
#      'data': {},
#      'defaultStyle': {}},
#     {'create_date': '2019-01-15T00:00:00',
#      'icon': 'account_balance',
#      'id': 'account_103',
#      'is_different_bank': 0,
#      'data': {},
#      'defaultStyle': {}},
#     {'create_date': '2019-01-03T00:00:00',
#      'icon': 'account_balance',
#      'id': 'account_901',
#      'is_different_bank': 0,
#      'data': {},
#      'defaultStyle': {}},
#     {'create_date': '2019-01-10T00:00:00',
#      'icon': 'account_balance',
#      'id': 'account_902',
#      'is_different_bank': 0,
#      'data': {},
#      'defaultStyle': {}},
#     {'create_date': '2019-01-09T00:00:00',
#      'icon': 'account_balance',
#      'id': 'account_903',
#      'is_different_bank': 1,
#      'data': {},
#      'defaultStyle': {}},
#     {'create_date': '2019-01-08T00:00:00',
#      'icon': 'account_balance',
#      'id': 'account_904',
#      'is_different_bank': 1,
#      'data': {},
#      'defaultStyle': {}},
#     {'icon': 'account_box',
#      'id': 'customer_7',
#      'data': {},
#      'defaultStyle': {},
#      'address': '-',
#      'customer_type': 'retail',
#      'first_name': '-',
#      'last_name': '-',
#      'phone': '-',
#      'remarks': "high-value IB txn into customer 103's account",
#      'risk_category': 'medium',
#      'risk_score': 50},
#     {'icon': 'account_box',
#      'id': 'customer_20',
#      'data': {},
#      'defaultStyle': {},
#      'address': '-',
#      'customer_type': 'retail',
#      'first_name': '-',
#      'last_name': '-',
#      'phone': '-',
#      'remarks': "high-value IB txn into customer 103's account",
#      'risk_category': 'medium',
#      'risk_score': 50},
#     {'icon': 'account_box',
#      'id': 'customer_55',
#      'data': {},
#      'defaultStyle': {},
#      'address': '-',
#      'customer_type': 'retail',
#      'first_name': '-',
#      'last_name': '-',
#      'phone': '-',
#      'remarks': "high-value IB txn into customer 103's account",
#      'risk_category': 'medium',
#      'risk_score': 50},
#     {'icon': 'account_box',
#      'id': 'customer_81',
#      'data': {},
#      'defaultStyle': {},
#      'address': '-',
#      'customer_type': 'retail',
#      'first_name': '-',
#      'last_name': '-',
#      'phone': '-',
#      'remarks': "high-value IB txn into customer 103's account",
#      'risk_category': 'medium',
#      'risk_score': 50},
#     {'icon': 'account_box',
#      'id': 'customer_103',
#      'data': {},
#      'defaultStyle': {},
#      'address': '103 RD',
#      'customer_type': 'retail',
#      'first_name': 'john',
#      'last_name': 'doe',
#      'phone': '+65 0000 0103',
#      'remarks': 'high-value purchases from luxury retailer. source of funds from 4 related accounts',
#      'risk_category': 'high',
#      'risk_score': 99},
#     {'icon': 'account_box',
#      'id': 'customer_901',
#      'data': {},
#      'defaultStyle': {},
#      'address': '901 RD',
#      'customer_type': 'retail',
#      'first_name': 'jane',
#      'last_name': 'doe',
#      'phone': '+65 0000 0103',
#      'remarks': "source of funds for customer 103's purchase of luxury items. customer has same phone number as customer 103.",
#      'risk_category': 'medium',
#      'risk_score': 74},
#     {'icon': 'account_box',
#      'id': 'customer_902',
#      'data': {},
#      'defaultStyle': {},
#      'address': '103 RD',
#      'customer_type': 'retail',
#      'first_name': 'jim',
#      'last_name': 'smith',
#      'phone': '+65 0000 0902',
#      'remarks': "source of funds for customer 103's purchase of luxury items. customer has same address as customer 103.",
#      'risk_category': 'medium',
#      'risk_score': 74},
#     {'icon': '-',
#      'id': 'other_banks',
#      'data': {},
#      'defaultStyle': {},
#      'address': '-',
#      'customer_type': '-',
#      'first_name': '-',
#      'last_name': '-',
#      'phone': '-',
#      'remarks': 'other banks',
#      'risk_category': '-',
#      'risk_score': '-'}],
#    'edges': [{'amount': 1000000,
#      'balance': 200000,
#      'category': 'ib_txn',
#      'date': '2020-01-01T00:00:00',
#      'id': 'ib_txn_1',
#      'is_foreign_source': 0,
#      'is_foreign_target': 1,
#      'is_high_risk_source_target_location': 0,
#      'relation': 'ib_transfer',
#      'source': 'account_103',
#      'source_owner': 'customer_103',
#      'target': 'account_904',
#      'target_owner': 'other_banks',
#      'time': '00:00:00',
#      'data': {},
#      'defaultStyle': {}},
#     {'amount': 100000,
#      'balance': '-',
#      'category': 'ib_txn',
#      'date': '2020-01-02T01:00:00',
#      'id': 'ib_txn_2',
#      'is_foreign_source': 1,
#      'is_foreign_target': 0,
#      'is_high_risk_source_target_location': 0,
#      'relation': 'ib_transfer',
#      'source': 'account_903',
#      'source_owner': 'other_banks',
#      'target': 'account_103',
#      'target_owner': 'customer_103',
#      'time': '01:00:00',
#      'data': {},
#      'defaultStyle': {}},
#     {'amount': 50000,
#      'balance': 250000,
#      'category': 'ib_txn',
#      'date': '2020-01-02T02:00:00',
#      'id': 'ib_txn_3',
#      'is_foreign_source': 0,
#      'is_foreign_target': 1,
#      'is_high_risk_source_target_location': 0,
#      'relation': 'ib_transfer',
#      'source': 'account_103',
#      'source_owner': 'customer_103',
#      'target': 'account_904',
#      'target_owner': 'other_banks',
#      'time': '02:00:00',
#      'data': {},
#      'defaultStyle': {}},
#     {'amount': 2000000,
#      'balance': '-',
#      'category': 'ib_txn',
#      'date': '2020-01-01T03:00:00',
#      'id': 'ib_txn_4',
#      'is_foreign_source': 1,
#      'is_foreign_target': 0,
#      'is_high_risk_source_target_location': 0,
#      'relation': 'ib_transfer',
#      'source': 'account_904',
#      'source_owner': 'other_banks',
#      'target': 'account_103',
#      'target_owner': 'customer_103',
#      'time': '03:00:00',
#      'data': {},
#      'defaultStyle': {}},
#     {'amount': 1000000,
#      'balance': 1250000,
#      'category': 'ib_txn',
#      'date': '2020-01-02T04:00:00',
#      'id': 'ib_txn_5',
#      'is_foreign_source': 0,
#      'is_foreign_target': 1,
#      'is_high_risk_source_target_location': 0,
#      'relation': 'ib_transfer',
#      'source': 'account_103',
#      'source_owner': 'customer_103',
#      'target': 'account_903',
#      'target_owner': 'other_banks',
#      'time': '04:00:00',
#      'data': {},
#      'defaultStyle': {}},
#     {'amount': 1000000,
#      'balance': 250000,
#      'category': 'ib_txn',
#      'date': '2020-01-02T05:00:00',
#      'id': 'ib_txn_6',
#      'is_foreign_source': 0,
#      'is_foreign_target': 1,
#      'is_high_risk_source_target_location': 0,
#      'relation': 'ib_transfer',
#      'source': 'account_103',
#      'source_owner': 'customer_103',
#      'target': 'account_903',
#      'target_owner': 'other_banks',
#      'time': '05:00:00',
#      'data': {},
#      'defaultStyle': {}},
#     {'amount': 250000,
#      'balance': 10000,
#      'category': 'ib_txn',
#      'date': '2020-01-01T06:00:00',
#      'id': 'ib_txn_7',
#      'is_foreign_source': 0,
#      'is_foreign_target': 0,
#      'is_high_risk_source_target_location': 0,
#      'relation': 'ib_transfer',
#      'source': 'account_901',
#      'source_owner': 'customer_901',
#      'target': 'account_103',
#      'target_owner': 'customer_103',
#      'time': '06:00:00',
#      'data': {},
#      'defaultStyle': {}},
#     {'amount': 250000,
#      'balance': 300000,
#      'category': 'ib_txn',
#      'date': '2020-01-01T06:30:00',
#      'id': 'ib_txn_8',
#      'is_foreign_source': 0,
#      'is_foreign_target': 0,
#      'is_high_risk_source_target_location': 0,
#      'relation': 'ib_transfer',
#      'source': 'account_902',
#      'source_owner': 'customer_902',
#      'target': 'account_103',
#      'target_owner': 'customer_103',
#      'time': '06:30:00',
#      'data': {},
#      'defaultStyle': {}},
#     {'amount': 250000,
#      'balance': '-',
#      'category': 'ib_txn',
#      'date': '2020-01-02T06:00:00',
#      'id': 'ib_txn_9',
#      'is_foreign_source': 1,
#      'is_foreign_target': 0,
#      'is_high_risk_source_target_location': 0,
#      'relation': 'ib_transfer',
#      'source': 'account_903',
#      'source_owner': 'other_banks',
#      'target': 'account_103',
#      'target_owner': 'customer_103',
#      'time': '06:00:00',
#      'data': {},
#      'defaultStyle': {}},
#     {'amount': 250000,
#      'balance': '-',
#      'category': 'ib_txn',
#      'date': '2020-01-01T00:00:00',
#      'id': 'ib_txn_10',
#      'is_foreign_source': 1,
#      'is_foreign_target': 0,
#      'is_high_risk_source_target_location': 0,
#      'relation': 'ib_transfer',
#      'source': 'account_904',
#      'source_owner': 'other_banks',
#      'target': 'account_103',
#      'target_owner': 'customer_103',
#      'time': '00:00:00',
#      'data': {},
#      'defaultStyle': {}},
#     {'amount': 125000,
#      'balance': 225000,
#      'category': 'ib_txn',
#      'date': '2020-01-03T22:00:00',
#      'id': 'ib_txn_72',
#      'is_foreign_source': 0,
#      'is_foreign_target': 0,
#      'is_high_risk_source_target_location': 0,
#      'relation': 'ib_transfer',
#      'source': 'account_7',
#      'source_owner': 'customer_7',
#      'target': 'account_103',
#      'target_owner': 'customer_103',
#      'time': '22:00:00',
#      'data': {},
#      'defaultStyle': {}},
#     {'amount': 250000,
#      'balance': 475000,
#      'category': 'ib_txn',
#      'date': '2020-01-03T22:00:00',
#      'id': 'ib_txn_73',
#      'is_foreign_source': 0,
#      'is_foreign_target': 0,
#      'is_high_risk_source_target_location': 0,
#      'relation': 'ib_transfer',
#      'source': 'account_55',
#      'source_owner': 'customer_55',
#      'target': 'account_103',
#      'target_owner': 'customer_103',
#      'time': '22:00:00',
#      'data': {},
#      'defaultStyle': {}},
#     {'amount': 150000,
#      'balance': 625000,
#      'category': 'ib_txn',
#      'date': '2020-01-04T18:00:00',
#      'id': 'ib_txn_74',
#      'is_foreign_source': 0,
#      'is_foreign_target': 0,
#      'is_high_risk_source_target_location': 0,
#      'relation': 'ib_transfer',
#      'source': 'account_20',
#      'source_owner': 'customer_20',
#      'target': 'account_103',
#      'target_owner': 'customer_103',
#      'time': '18:00:00',
#      'data': {},
#      'defaultStyle': {}},
#     {'amount': 300000,
#      'balance': 925000,
#      'category': 'ib_txn',
#      'date': '2020-01-04T18:00:00',
#      'id': 'ib_txn_75',
#      'is_foreign_source': 0,
#      'is_foreign_target': 0,
#      'is_high_risk_source_target_location': 0,
#      'relation': 'ib_transfer',
#      'source': 'account_81',
#      'source_owner': 'customer_81',
#      'target': 'account_103',
#      'target_owner': 'customer_103',
#      'time': '18:00:00',
#      'data': {},
#      'defaultStyle': {}},
#     {'category': 'ownership',
#      'id': 'ownership_210',
#      'relation': 'owns',
#      'source': 'customer_7',
#      'target': 'account_7',
#      'data': {},
#      'defaultStyle': {}},
#     {'category': 'ownership',
#      'id': 'ownership_223',
#      'relation': 'owns',
#      'source': 'customer_20',
#      'target': 'account_20',
#      'data': {},
#      'defaultStyle': {}},
#     {'category': 'ownership',
#      'id': 'ownership_258',
#      'relation': 'owns',
#      'source': 'customer_55',
#      'target': 'account_55',
#      'data': {},
#      'defaultStyle': {}},
#     {'category': 'ownership',
#      'id': 'ownership_284',
#      'relation': 'owns',
#      'source': 'customer_81',
#      'target': 'account_81',
#      'data': {},
#      'defaultStyle': {}},
#     {'category': 'ownership',
#      'id': 'ownership_306',
#      'relation': 'owns',
#      'source': 'customer_103',
#      'target': 'account_103',
#      'data': {},
#      'defaultStyle': {}},
#     {'category': 'ownership',
#      'id': 'ownership_307',
#      'relation': 'owns',
#      'source': 'customer_901',
#      'target': 'account_901',
#      'data': {},
#      'defaultStyle': {}},
#     {'category': 'ownership',
#      'id': 'ownership_308',
#      'relation': 'owns',
#      'source': 'customer_902',
#      'target': 'account_902',
#      'data': {},
#      'defaultStyle': {}},
#     {'category': 'ownership',
#      'id': 'ownership_310',
#      'relation': 'owns',
#      'source': 'other_banks',
#      'target': 'account_903',
#      'data': {},
#      'defaultStyle': {}},
#     {'category': 'ownership',
#      'id': 'ownership_311',
#      'relation': 'owns',
#      'source': 'other_banks',
#      'target': 'account_904',
#      'data': {},
#      'defaultStyle': {}}],
#    'metadata': {'fields': {'nodes': [{'name': 'create_date',
#        'format': 'YYYY-M-DTH:m:s',
#        'type': 'timestamp',
#        'analyzerType': 'DATETIME'},
#       {'name': 'icon',
#        'format': '',
#        'type': 'string',
#        'analyzerType': 'STRING'},
#       {'name': 'id', 'format': '', 'type': 'string', 'analyzerType': 'STRING'},
#       {'name': 'is_different_bank',
#        'format': '',
#        'type': 'integer',
#        'analyzerType': 'INT'},
#       {'name': 'address',
#        'format': '',
#        'type': 'string',
#        'analyzerType': 'STRING'},
#       {'name': 'customer_type',
#        'format': '',
#        'type': 'string',
#        'analyzerType': 'STRING'},
#       {'name': 'first_name',
#        'format': '',
#        'type': 'string',
#        'analyzerType': 'STRING'},
#       {'name': 'last_name',
#        'format': '',
#        'type': 'string',
#        'analyzerType': 'STRING'},
#       {'name': 'phone',
#        'format': '',
#        'type': 'string',
#        'analyzerType': 'STRING'},
#       {'name': 'remarks',
#        'format': '',
#        'type': 'string',
#        'analyzerType': 'STRING'},
#       {'name': 'risk_category',
#        'format': '',
#        'type': 'string',
#        'analyzerType': 'STRING'},
#       {'name': 'risk_score',
#        'format': '',
#        'type': 'integer',
#        'analyzerType': 'INT'}],
#      'edges': [{'name': 'amount',
#        'format': '',
#        'type': 'integer',
#        'analyzerType': 'INT'},
#       {'name': 'category',
#        'format': '',
#        'type': 'string',
#        'analyzerType': 'STRING'},
#       {'name': 'date',
#        'format': 'YYYY-M-DTH:m:s',
#        'type': 'timestamp',
#        'analyzerType': 'DATETIME'},
#       {'name': 'id', 'format': '', 'type': 'string', 'analyzerType': 'STRING'},
#       {'name': 'is_foreign_source',
#        'format': '',
#        'type': 'integer',
#        'analyzerType': 'INT'},
#       {'name': 'is_foreign_target',
#        'format': '',
#        'type': 'integer',
#        'analyzerType': 'INT'},
#       {'name': 'is_high_risk_source_target_location',
#        'format': '',
#        'type': 'integer',
#        'analyzerType': 'INT'},
#       {'name': 'relation',
#        'format': '',
#        'type': 'string',
#        'analyzerType': 'STRING'},
#       {'name': 'source',
#        'format': '',
#        'type': 'string',
#        'analyzerType': 'STRING'},
#       {'name': 'source_owner',
#        'format': '',
#        'type': 'string',
#        'analyzerType': 'STRING'},
#       {'name': 'target',
#        'format': '',
#        'type': 'string',
#        'analyzerType': 'STRING'},
#       {'name': 'target_owner',
#        'format': '',
#        'type': 'string',
#        'analyzerType': 'STRING'},
#       {'name': 'time',
#        'format': 'H:m:s',
#        'type': 'time',
#        'analyzerType': 'TIME'}]},
#     'title': 'Banking Connections',
#     'key': 'K6T5dLXLY',
#     'groupEdges': {'toggle': True, 'availability': True},
#     'visible': False}},
#   {'nodes': [{'id': 'new_cust', 'value': 'new_cust', 'name': 'new_cust'},
#     {'id': 'x_investments', 'value': 'x_investments', 'name': 'x_investments'},
#     {'id': 'existing_cust', 'value': 'existing_cust', 'name': 'existing_cust'},
#     {'id': 'x_insurance', 'value': 'x_insurance', 'name': 'x_insurance'},
#     {'id': 'x_savings', 'value': 'x_savings', 'name': 'x_savings'},
#     {'id': 'competitor_4', 'value': 'competitor_4', 'name': 'competitor_4'},
#     {'id': 'competitor_2', 'value': 'competitor_2', 'name': 'competitor_2'},
#     {'id': 'competitor_1', 'value': 'competitor_1', 'name': 'competitor_1'},
#     {'id': 'competitor_5', 'value': 'competitor_5', 'name': 'competitor_5'},
#     {'id': 'competitor_3', 'value': 'competitor_3', 'name': 'competitor_3'}],
#    'edges': [{'date': '2020-06-09',
#      'source_type': 'customer_001',
#      'age_group': '18-34',
#      'amount': 4488,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 0,
#      'id': 'rmGP15cUK'},
#     {'date': '2020-06-06',
#      'source_type': 'customer_002',
#      'age_group': '18-34',
#      'amount': 4587,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 1,
#      'id': 'kLXHvtixIW'},
#     {'date': '2020-06-03',
#      'source_type': 'customer_003',
#      'age_group': '18-34',
#      'amount': 3779,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 2,
#      'id': 'hnfvSiqPSU'},
#     {'date': '2020-10-08',
#      'source_type': 'customer_004',
#      'age_group': '18-34',
#      'amount': 5701,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 3,
#      'id': 'pCECSrSrKM'},
#     {'date': '2020-08-16',
#      'source_type': 'customer_005',
#      'age_group': '18-34',
#      'amount': 4279,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 4,
#      'id': '1gd3LJr77x'},
#     {'date': '2020-11-24',
#      'source_type': 'customer_006',
#      'age_group': '18-34',
#      'amount': 5782,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 5,
#      'id': 'GoWSq0Tr6Q'},
#     {'date': '2020-07-24',
#      'source_type': 'customer_007',
#      'age_group': '18-34',
#      'amount': 5811,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 6,
#      'id': 'Gn7OAoWaF6'},
#     {'date': '2020-08-27',
#      'source_type': 'customer_008',
#      'age_group': '18-34',
#      'amount': 3917,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 7,
#      'id': 'CNrUoN_NZl'},
#     {'date': '2020-11-17',
#      'source_type': 'customer_009',
#      'age_group': '18-34',
#      'amount': 3909,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 8,
#      'id': '-SGWFrIJyr'},
#     {'date': '2020-09-15',
#      'source_type': 'customer_010',
#      'age_group': '18-34',
#      'amount': 6531,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 9,
#      'id': '4sEya6Jhog'},
#     {'date': '2020-10-12',
#      'source_type': 'customer_011',
#      'age_group': '18-34',
#      'amount': 5559,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 10,
#      'id': '7bYL86RQqH'},
#     {'date': '2020-08-30',
#      'source_type': 'customer_012',
#      'age_group': '18-34',
#      'amount': 5646,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 11,
#      'id': 'fdCGuXHE3R'},
#     {'date': '2020-07-07',
#      'source_type': 'customer_013',
#      'age_group': '18-34',
#      'amount': 2708,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 12,
#      'id': '70tnGDJGqp'},
#     {'date': '2020-09-18',
#      'source_type': 'customer_014',
#      'age_group': '18-34',
#      'amount': 6571,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 13,
#      'id': 'py7afmk-WG'},
#     {'date': '2020-07-18',
#      'source_type': 'customer_015',
#      'age_group': '18-34',
#      'amount': 3474,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 14,
#      'id': 'sDOuotqckb'},
#     {'date': '2020-10-10',
#      'source_type': 'customer_016',
#      'age_group': '18-34',
#      'amount': 7133,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 15,
#      'id': 'egCffNt8dz'},
#     {'date': '2020-09-12',
#      'source_type': 'customer_017',
#      'age_group': '18-34',
#      'amount': 7436,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 16,
#      'id': 'um3YrUW5n1e'},
#     {'date': '2020-09-20',
#      'source_type': 'customer_018',
#      'age_group': '18-34',
#      'amount': 3342,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 17,
#      'id': 'IjyJHk-H0s9'},
#     {'date': '2020-06-10',
#      'source_type': 'customer_019',
#      'age_group': '18-34',
#      'amount': 3293,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 18,
#      'id': 'PSAGdgh0-Tc'},
#     {'date': '2020-11-12',
#      'source_type': 'customer_020',
#      'age_group': '18-34',
#      'amount': 3596,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 19,
#      'id': '_yAYWudc2Xw'},
#     {'date': '2020-11-02',
#      'source_type': 'customer_021',
#      'age_group': '18-34',
#      'amount': 6726,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 20,
#      'id': 'YGWXxB_DulQ'},
#     {'date': '2020-10-10',
#      'source_type': 'customer_022',
#      'age_group': '18-34',
#      'amount': 3825,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 21,
#      'id': 'Kh96skBhkXV'},
#     {'date': '2020-11-08',
#      'source_type': 'customer_023',
#      'age_group': '18-34',
#      'amount': 7455,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 22,
#      'id': 'uQHTtlpvphW'},
#     {'date': '2020-08-17',
#      'source_type': 'customer_024',
#      'age_group': '18-34',
#      'amount': 6141,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 23,
#      'id': '2bg2Dq62nyq'},
#     {'date': '2020-12-18',
#      'source_type': 'customer_025',
#      'age_group': '18-34',
#      'amount': 7437,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 24,
#      'id': '7bp9WIO6ywz'},
#     {'date': '2020-08-23',
#      'source_type': 'customer_026',
#      'age_group': '18-34',
#      'amount': 6831,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 25,
#      'id': 'VcUEIM3dnwV'},
#     {'date': '2020-11-11',
#      'source_type': 'customer_027',
#      'age_group': '18-34',
#      'amount': 2265,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 26,
#      'id': 't5zBc0ddVrd'},
#     {'date': '2020-07-24',
#      'source_type': 'customer_028',
#      'age_group': '18-34',
#      'amount': 5973,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 27,
#      'id': '8jywmD10KKg'},
#     {'date': '2020-07-24',
#      'source_type': 'customer_029',
#      'age_group': '18-34',
#      'amount': 3960,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 28,
#      'id': 'pPBbARN_O0y'},
#     {'date': '2020-10-15',
#      'source_type': 'customer_115',
#      'age_group': '51-64',
#      'amount': 4564,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 29,
#      'id': '608AIjk4HmF'},
#     {'date': '2020-10-11',
#      'source_type': 'customer_117',
#      'age_group': '51-64',
#      'amount': 2667,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 30,
#      'id': 'vTERirMYGX3'},
#     {'date': '2020-12-30',
#      'source_type': 'customer_119',
#      'age_group': '18-34',
#      'amount': 4029,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 31,
#      'id': 'QOTxdBKAtNU'},
#     {'date': '2020-12-25',
#      'source_type': 'customer_122',
#      'age_group': '51-64',
#      'amount': 3502,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 32,
#      'id': 'QRXqrocJB5Q'},
#     {'date': '2020-09-19',
#      'source_type': 'customer_124',
#      'age_group': '51-64',
#      'amount': 4994,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 33,
#      'id': 'ht4KbxsnF1Z'},
#     {'date': '2020-07-08',
#      'source_type': 'customer_164',
#      'age_group': '65+',
#      'amount': 4261,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 34,
#      'id': 'Y-8fWN8wN-X'},
#     {'date': '2020-09-04',
#      'source_type': 'customer_167',
#      'age_group': '18-34',
#      'amount': 4266,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 35,
#      'id': 'aA4pa1-X8Ne'},
#     {'date': '2020-08-07',
#      'source_type': 'customer_169',
#      'age_group': '65+',
#      'amount': 2119,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 36,
#      'id': 'hTQEdZmktaa'},
#     {'date': '2020-06-19',
#      'source_type': 'customer_171',
#      'age_group': '65+',
#      'amount': 3705,
#      'source': 'new_cust',
#      'target': 'x_investments',
#      'key': 37,
#      'id': 'Y0SKBigGcNR'},
#     {'date': '2020-06-27',
#      'source_type': 'customer_089',
#      'age_group': '35-50',
#      'amount': 1003,
#      'source': 'new_cust',
#      'target': 'x_savings',
#      'key': 0,
#      'id': 'v33tBYhY8gp'},
#     {'date': '2020-06-04',
#      'source_type': 'customer_112',
#      'age_group': '51-64',
#      'amount': 876,
#      'source': 'new_cust',
#      'target': 'x_savings',
#      'key': 1,
#      'id': 'xVexse0HF5a'},
#     {'date': '2020-06-13',
#      'source_type': 'customer_113',
#      'age_group': '51-64',
#      'amount': 9263,
#      'source': 'new_cust',
#      'target': 'x_savings',
#      'key': 2,
#      'id': 'wYIT3nbuGk0'},
#     {'date': '2020-10-15',
#      'source_type': 'customer_165',
#      'age_group': '35-50',
#      'amount': 1799,
#      'source': 'new_cust',
#      'target': 'x_savings',
#      'key': 3,
#      'id': 'YG_fWD88OI7'},
#     {'date': '2020-09-20',
#      'source_type': 'customer_172',
#      'age_group': '51-64',
#      'amount': 4047,
#      'source': 'new_cust',
#      'target': 'x_savings',
#      'key': 4,
#      'id': 'lE1xAYIEMpR'},
#     {'date': '2020-07-18',
#      'source_type': 'customer_116',
#      'age_group': '35-50',
#      'amount': 3077,
#      'source': 'new_cust',
#      'target': 'x_insurance',
#      'key': 0,
#      'id': 'yfve9RhQFVs'},
#     {'date': '2020-07-02',
#      'source_type': 'customer_118',
#      'age_group': '65+',
#      'amount': 4435,
#      'source': 'new_cust',
#      'target': 'x_insurance',
#      'key': 1,
#      'id': 'n6J8yga3tMC'},
#     {'date': '2020-08-15',
#      'source_type': 'customer_120',
#      'age_group': '65+',
#      'amount': 1552,
#      'source': 'new_cust',
#      'target': 'x_insurance',
#      'key': 2,
#      'id': 'eIPFZJrJLNV'},
#     {'date': '2020-09-10',
#      'source_type': 'customer_121',
#      'age_group': '65+',
#      'amount': 4240,
#      'source': 'new_cust',
#      'target': 'x_insurance',
#      'key': 3,
#      'id': 'yDAu92zNi-6'},
#     {'date': '2020-09-09',
#      'source_type': 'customer_123',
#      'age_group': '35-50',
#      'amount': 4136,
#      'source': 'new_cust',
#      'target': 'x_insurance',
#      'key': 4,
#      'id': 'Mh7wiXXIcbD'},
#     {'date': '2020-09-27',
#      'source_type': 'customer_166',
#      'age_group': '35-50',
#      'amount': 1133,
#      'source': 'new_cust',
#      'target': 'x_insurance',
#      'key': 5,
#      'id': 'nU9OI1oyKBE'},
#     {'date': '2020-07-05',
#      'source_type': 'customer_168',
#      'age_group': '18-34',
#      'amount': 1671,
#      'source': 'new_cust',
#      'target': 'x_insurance',
#      'key': 6,
#      'id': 'bRlLVWkf27R'},
#     {'date': '2020-11-18',
#      'source_type': 'customer_170',
#      'age_group': '35-50',
#      'amount': 3669,
#      'source': 'new_cust',
#      'target': 'x_insurance',
#      'key': 7,
#      'id': 'tXYlOmr8ws-'},
#     {'date': '2020-07-16',
#      'source_type': 'customer_173',
#      'age_group': '65+',
#      'amount': 1113,
#      'source': 'new_cust',
#      'target': 'x_insurance',
#      'key': 8,
#      'id': 'i4tBvgcu1q3'},
#     {'date': '2020-06-05',
#      'source_type': 'customer_057',
#      'age_group': '65+',
#      'amount': 8981,
#      'source': 'x_investments',
#      'target': 'x_savings',
#      'key': 0,
#      'id': 'fw3iTTYz4pA'},
#     {'date': '2020-06-19',
#      'source_type': 'customer_058',
#      'age_group': '65+',
#      'amount': 1033,
#      'source': 'x_investments',
#      'target': 'x_savings',
#      'key': 1,
#      'id': 'AVC78aGtS1F'},
#     {'date': '2020-06-05',
#      'source_type': 'customer_067',
#      'age_group': '35-50',
#      'amount': 2548,
#      'source': 'x_investments',
#      'target': 'x_savings',
#      'key': 2,
#      'id': 'gS-YGTvk3KK'},
#     {'date': '2020-06-20',
#      'source_type': 'customer_081',
#      'age_group': '35-50',
#      'amount': 1001,
#      'source': 'x_investments',
#      'target': 'x_savings',
#      'key': 3,
#      'id': 'eQr7goGb8KE'},
#     {'date': '2020-06-10',
#      'source_type': 'customer_094',
#      'age_group': '35-50',
#      'amount': 1688,
#      'source': 'x_investments',
#      'target': 'x_savings',
#      'key': 4,
#      'id': 'xSG_Hoqq781'},
#     {'date': '2020-06-14',
#      'source_type': 'customer_109',
#      'age_group': '51-64',
#      'amount': 1740,
#      'source': 'x_investments',
#      'target': 'x_savings',
#      'key': 5,
#      'id': 'rQPlEGNfhyr'},
#     {'date': '2020-06-03',
#      'source_type': 'customer_114',
#      'age_group': '18-34',
#      'amount': 2921,
#      'source': 'x_investments',
#      'target': 'x_savings',
#      'key': 6,
#      'id': 'ZnM0zTd4qNw'},
#     {'date': '2020-10-28',
#      'source_type': 'customer_144',
#      'age_group': '18-34',
#      'amount': 4233,
#      'source': 'x_investments',
#      'target': 'competitor_4',
#      'key': 0,
#      'id': 'Ufx-5wxkT08'},
#     {'date': '2020-12-19',
#      'source_type': 'customer_145',
#      'age_group': '18-34',
#      'amount': 2703,
#      'source': 'x_investments',
#      'target': 'competitor_4',
#      'key': 1,
#      'id': 'SmMjZSUK4rY'},
#     {'date': '2020-12-24',
#      'source_type': 'customer_146',
#      'age_group': '51-64',
#      'amount': 2854,
#      'source': 'x_investments',
#      'target': 'competitor_5',
#      'key': 0,
#      'id': '2UWd8XCkUwc'},
#     {'date': '2020-06-11',
#      'source_type': 'customer_151',
#      'age_group': '65+',
#      'amount': 1740,
#      'source': 'x_investments',
#      'target': 'competitor_5',
#      'key': 1,
#      'id': 'CFfeeM5teOs'},
#     {'date': '2020-12-23',
#      'source_type': 'customer_147',
#      'age_group': '18-34',
#      'amount': 2494,
#      'source': 'x_investments',
#      'target': 'competitor_1',
#      'key': 0,
#      'id': 'dQa02k5dMTj'},
#     {'date': '2020-10-02',
#      'source_type': 'customer_152',
#      'age_group': '51-64',
#      'amount': 2022,
#      'source': 'x_investments',
#      'target': 'competitor_1',
#      'key': 1,
#      'id': 'tS3dxrNKIlt'},
#     {'date': '2020-10-06',
#      'source_type': 'customer_148',
#      'age_group': '35-50',
#      'amount': 3656,
#      'source': 'x_investments',
#      'target': 'competitor_2',
#      'key': 0,
#      'id': 'oRBModBpxY0'},
#     {'date': '2020-10-15',
#      'source_type': 'customer_149',
#      'age_group': '35-50',
#      'amount': 1878,
#      'source': 'x_investments',
#      'target': 'competitor_2',
#      'key': 1,
#      'id': 'V1cLkjJ4BTa'},
#     {'date': '2020-12-16',
#      'source_type': 'customer_150',
#      'age_group': '18-34',
#      'amount': 2130,
#      'source': 'x_investments',
#      'target': 'competitor_2',
#      'key': 2,
#      'id': 'ak9nC3DXrIN'},
#     {'date': '2020-10-20',
#      'source_type': 'customer_153',
#      'age_group': '35-50',
#      'amount': 1016,
#      'source': 'x_investments',
#      'target': 'competitor_2',
#      'key': 3,
#      'id': '5jZECIkW875'},
#     {'date': '2020-06-16',
#      'source_type': 'customer_030',
#      'age_group': '65+',
#      'amount': 1295,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 0,
#      'id': '8EwRrOOZtxI'},
#     {'date': '2020-11-23',
#      'source_type': 'customer_031',
#      'age_group': '35-50',
#      'amount': 3640,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 1,
#      'id': '5x3FKY0P93L'},
#     {'date': '2020-07-22',
#      'source_type': 'customer_032',
#      'age_group': '18-34',
#      'amount': 1206,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 2,
#      'id': 'z_uiX0aRaJf'},
#     {'date': '2020-11-25',
#      'source_type': 'customer_033',
#      'age_group': '51-64',
#      'amount': 1236,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 3,
#      'id': '-o1CEOYHbP3'},
#     {'date': '2020-10-30',
#      'source_type': 'customer_034',
#      'age_group': '35-50',
#      'amount': 3753,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 4,
#      'id': 'ZR0sO8l4fKb'},
#     {'date': '2020-06-02',
#      'source_type': 'customer_035',
#      'age_group': '51-64',
#      'amount': 1790,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 5,
#      'id': 'kKDhn4h7fhR'},
#     {'date': '2020-10-12',
#      'source_type': 'customer_036',
#      'age_group': '35-50',
#      'amount': 3819,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 6,
#      'id': 'm55cwRHcwLp'},
#     {'date': '2020-09-16',
#      'source_type': 'customer_037',
#      'age_group': '65+',
#      'amount': 1499,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 7,
#      'id': 'h0UyLotbAVr'},
#     {'date': '2020-07-01',
#      'source_type': 'customer_038',
#      'age_group': '51-64',
#      'amount': 1314,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 8,
#      'id': '5oA5rLP7JZl'},
#     {'date': '2020-07-04',
#      'source_type': 'customer_039',
#      'age_group': '51-64',
#      'amount': 1404,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 9,
#      'id': 'VNnnZpLtOSc'},
#     {'date': '2020-12-09',
#      'source_type': 'customer_040',
#      'age_group': '35-50',
#      'amount': 3522,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 10,
#      'id': 'qkdfKe_okP2'},
#     {'date': '2020-11-01',
#      'source_type': 'customer_041',
#      'age_group': '65+',
#      'amount': 585,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 11,
#      'id': 'SwO1Fsj0wos'},
#     {'date': '2020-12-18',
#      'source_type': 'customer_042',
#      'age_group': '35-50',
#      'amount': 3559,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 12,
#      'id': 'd8NUp9A23kW'},
#     {'date': '2020-12-29',
#      'source_type': 'customer_043',
#      'age_group': '65+',
#      'amount': 1343,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 13,
#      'id': 'j5GjN5spxL4'},
#     {'date': '2020-08-11',
#      'source_type': 'customer_044',
#      'age_group': '51-64',
#      'amount': 1196,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 14,
#      'id': '0O7aNxctt8i'},
#     {'date': '2020-06-01',
#      'source_type': 'customer_045',
#      'age_group': '35-50',
#      'amount': 3245,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 15,
#      'id': 'lk9budbaPVN'},
#     {'date': '2020-08-27',
#      'source_type': 'customer_046',
#      'age_group': '65+',
#      'amount': 1878,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 16,
#      'id': 'QSms5dXxSpM'},
#     {'date': '2020-08-31',
#      'source_type': 'customer_047',
#      'age_group': '65+',
#      'amount': 1231,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 17,
#      'id': 'a1lsVIwRM1D'},
#     {'date': '2020-07-10',
#      'source_type': 'customer_048',
#      'age_group': '18-34',
#      'amount': 1379,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 18,
#      'id': 'Na2o6SOLycP'},
#     {'date': '2020-10-26',
#      'source_type': 'customer_049',
#      'age_group': '35-50',
#      'amount': 4341,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 19,
#      'id': 'k7ZYxZMqfbZ'},
#     {'date': '2020-10-22',
#      'source_type': 'customer_155',
#      'age_group': '35-50',
#      'amount': 2778,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 20,
#      'id': 'LNBXSB_k6hB'},
#     {'date': '2020-12-19',
#      'source_type': 'customer_157',
#      'age_group': '51-64',
#      'amount': 1726,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 21,
#      'id': 'HB06YT0KafW'},
#     {'date': '2020-10-28',
#      'source_type': 'customer_158',
#      'age_group': '51-64',
#      'amount': 3920,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 22,
#      'id': 'VEd7Xp59YUq'},
#     {'date': '2020-10-07',
#      'source_type': 'customer_162',
#      'age_group': '65+',
#      'amount': 1230,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 23,
#      'id': 'rNlouKfamfI'},
#     {'date': '2020-12-18',
#      'source_type': 'customer_163',
#      'age_group': '51-64',
#      'amount': 4515,
#      'source': 'existing_cust',
#      'target': 'x_insurance',
#      'key': 24,
#      'id': 'gwcu10QiiJ1'},
#     {'date': '2020-06-11',
#      'source_type': 'customer_050',
#      'age_group': '18-34',
#      'amount': 5064,
#      'source': 'existing_cust',
#      'target': 'x_savings',
#      'key': 0,
#      'id': '-Y6L4R5Ok6U'},
#     {'date': '2020-06-06',
#      'source_type': 'customer_071',
#      'age_group': '35-50',
#      'amount': 9869,
#      'source': 'existing_cust',
#      'target': 'x_savings',
#      'key': 1,
#      'id': 'j3Xtid3jAyU'},
#     {'date': '2020-06-27',
#      'source_type': 'customer_076',
#      'age_group': '65+',
#      'amount': 4906,
#      'source': 'existing_cust',
#      'target': 'x_savings',
#      'key': 2,
#      'id': 'h6j2NFSB0g4'},
#     {'date': '2020-12-14',
#      'source_type': 'customer_156',
#      'age_group': '51-64',
#      'amount': 3533,
#      'source': 'existing_cust',
#      'target': 'x_savings',
#      'key': 3,
#      'id': '6P1znLduP0Y'},
#     {'date': '2020-11-09',
#      'source_type': 'customer_159',
#      'age_group': '35-50',
#      'amount': 2637,
#      'source': 'existing_cust',
#      'target': 'x_savings',
#      'key': 4,
#      'id': 'db8R2DZs0zn'},
#     {'date': '2020-11-05',
#      'source_type': 'customer_161',
#      'age_group': '18-34',
#      'amount': 2731,
#      'source': 'existing_cust',
#      'target': 'x_savings',
#      'key': 5,
#      'id': 'L8EdKbBagN8'},
#     {'date': '2020-06-23',
#      'source_type': 'customer_154',
#      'age_group': '51-64',
#      'amount': 3930,
#      'source': 'existing_cust',
#      'target': 'x_investments',
#      'key': 0,
#      'id': 'QSHWxmIlIRB'},
#     {'date': '2020-12-31',
#      'source_type': 'customer_160',
#      'age_group': '51-64',
#      'amount': 3639,
#      'source': 'existing_cust',
#      'target': 'x_investments',
#      'key': 1,
#      'id': 'wg8QMNQe5Ru'},
#     {'date': '2020-06-22',
#      'source_type': 'customer_051',
#      'age_group': '51-64',
#      'amount': 5161,
#      'source': 'x_insurance',
#      'target': 'x_savings',
#      'key': 0,
#      'id': 'Zoy7HZnM-M8'},
#     {'date': '2020-06-14',
#      'source_type': 'customer_053',
#      'age_group': '51-64',
#      'amount': 4463,
#      'source': 'x_insurance',
#      'target': 'x_savings',
#      'key': 1,
#      'id': 'Zue1vsP-SU1'},
#     {'date': '2020-06-16',
#      'source_type': 'customer_060',
#      'age_group': '35-50',
#      'amount': 599,
#      'source': 'x_insurance',
#      'target': 'x_savings',
#      'key': 2,
#      'id': 'J6pXwrzXFHR'},
#     {'date': '2020-06-27',
#      'source_type': 'customer_069',
#      'age_group': '51-64',
#      'amount': 591,
#      'source': 'x_insurance',
#      'target': 'x_savings',
#      'key': 3,
#      'id': '9yjq20z2kAm'},
#     {'date': '2020-06-16',
#      'source_type': 'customer_073',
#      'age_group': '65+',
#      'amount': 4901,
#      'source': 'x_insurance',
#      'target': 'x_savings',
#      'key': 4,
#      'id': 'T9RGN5fFvfI'},
#     {'date': '2020-06-15',
#      'source_type': 'customer_080',
#      'age_group': '51-64',
#      'amount': 9594,
#      'source': 'x_insurance',
#      'target': 'x_savings',
#      'key': 5,
#      'id': 'tGbEX-JtLOR'},
#     {'date': '2020-06-18',
#      'source_type': 'customer_082',
#      'age_group': '35-50',
#      'amount': 4210,
#      'source': 'x_insurance',
#      'target': 'x_savings',
#      'key': 6,
#      'id': 'ORnDZrKfhvy'},
#     {'date': '2020-06-19',
#      'source_type': 'customer_090',
#      'age_group': '18-34',
#      'amount': 9076,
#      'source': 'x_insurance',
#      'target': 'x_savings',
#      'key': 7,
#      'id': 'Id4fJ9yswLA'},
#     {'date': '2020-06-06',
#      'source_type': 'customer_105',
#      'age_group': '18-34',
#      'amount': 1488,
#      'source': 'x_insurance',
#      'target': 'x_savings',
#      'key': 8,
#      'id': '-MU_scoLhhN'},
#     {'date': '2020-07-31',
#      'source_type': 'customer_135',
#      'age_group': '65+',
#      'amount': 2456,
#      'source': 'x_insurance',
#      'target': 'competitor_2',
#      'key': 0,
#      'id': 'QQRIm8L22CY'},
#     {'date': '2020-11-01',
#      'source_type': 'customer_141',
#      'age_group': '18-34',
#      'amount': 1897,
#      'source': 'x_insurance',
#      'target': 'competitor_2',
#      'key': 1,
#      'id': 'OlqDKRhY9EO'},
#     {'date': '2020-06-23',
#      'source_type': 'customer_136',
#      'age_group': '65+',
#      'amount': 2865,
#      'source': 'x_insurance',
#      'target': 'competitor_3',
#      'key': 0,
#      'id': 'loay6TiGfKF'},
#     {'date': '2020-09-08',
#      'source_type': 'customer_138',
#      'age_group': '51-64',
#      'amount': 4400,
#      'source': 'x_insurance',
#      'target': 'competitor_3',
#      'key': 1,
#      'id': 'kq8OL9zlUMc'},
#     {'date': '2020-08-28',
#      'source_type': 'customer_137',
#      'age_group': '35-50',
#      'amount': 2013,
#      'source': 'x_insurance',
#      'target': 'competitor_5',
#      'key': 0,
#      'id': 'K9LWY-ormeb'},
#     {'date': '2020-08-17',
#      'source_type': 'customer_139',
#      'age_group': '65+',
#      'amount': 3069,
#      'source': 'x_insurance',
#      'target': 'competitor_5',
#      'key': 1,
#      'id': 'pHs6qTIdy_Q'},
#     {'date': '2020-08-06',
#      'source_type': 'customer_143',
#      'age_group': '35-50',
#      'amount': 3593,
#      'source': 'x_insurance',
#      'target': 'competitor_5',
#      'key': 2,
#      'id': '5fKvzvDz_q8'},
#     {'date': '2020-10-01',
#      'source_type': 'customer_140',
#      'age_group': '51-64',
#      'amount': 2810,
#      'source': 'x_insurance',
#      'target': 'competitor_1',
#      'key': 0,
#      'id': 'pS5uLoXrwKu'},
#     {'date': '2020-09-12',
#      'source_type': 'customer_142',
#      'age_group': '51-64',
#      'amount': 3366,
#      'source': 'x_insurance',
#      'target': 'competitor_4',
#      'key': 0,
#      'id': 'z6pJ85XG_7K'},
#     {'date': '2021-01-12',
#      'source_type': 'customer_050',
#      'age_group': '18-34',
#      'amount': 5064,
#      'source': 'x_savings',
#      'target': 'competitor_4',
#      'key': 0,
#      'id': '9Vlm2UdXIBm'},
#     {'date': '2021-01-07',
#      'source_type': 'customer_051',
#      'age_group': '51-64',
#      'amount': 5161,
#      'source': 'x_savings',
#      'target': 'competitor_4',
#      'key': 1,
#      'id': 'hvdEzP0nk3h'},
#     {'date': '2021-01-10',
#      'source_type': 'customer_057',
#      'age_group': '65+',
#      'amount': 8981,
#      'source': 'x_savings',
#      'target': 'competitor_4',
#      'key': 2,
#      'id': 'aRU4Djv_Zi2'},
#     {'date': '2021-01-10',
#      'source_type': 'customer_059',
#      'age_group': '18-34',
#      'amount': 6075,
#      'source': 'x_savings',
#      'target': 'competitor_4',
#      'key': 3,
#      'id': '6NOT2CEHXMp'},
#     {'date': '2021-01-14',
#      'source_type': 'customer_063',
#      'age_group': '65+',
#      'amount': 1192,
#      'source': 'x_savings',
#      'target': 'competitor_4',
#      'key': 4,
#      'id': 'ktSE3NpKn5R'},
#     {'date': '2021-01-04',
#      'source_type': 'customer_064',
#      'age_group': '65+',
#      'amount': 661,
#      'source': 'x_savings',
#      'target': 'competitor_4',
#      'key': 5,
#      'id': 'nInwd-IeCRs'},
#     {'date': '2021-01-04',
#      'source_type': 'customer_065',
#      'age_group': '51-64',
#      'amount': 2532,
#      'source': 'x_savings',
#      'target': 'competitor_4',
#      'key': 6,
#      'id': 'wXvvSmnR_jW'},
#     {'date': '2021-01-05',
#      'source_type': 'customer_067',
#      'age_group': '35-50',
#      'amount': 2548,
#      'source': 'x_savings',
#      'target': 'competitor_4',
#      'key': 7,
#      'id': '5yxu1qsKjkr'},
#     {'date': '2021-01-14',
#      'source_type': 'customer_072',
#      'age_group': '18-34',
#      'amount': 9835,
#      'source': 'x_savings',
#      'target': 'competitor_4',
#      'key': 8,
#      'id': 'ApsbCXr-IUc'},
#     {'date': '2021-01-03',
#      'source_type': 'customer_078',
#      'age_group': '35-50',
#      'amount': 8852,
#      'source': 'x_savings',
#      'target': 'competitor_4',
#      'key': 9,
#      'id': '1acgbdzkkjO'},
#     {'date': '2021-01-04',
#      'source_type': 'customer_083',
#      'age_group': '35-50',
#      'amount': 7985,
#      'source': 'x_savings',
#      'target': 'competitor_4',
#      'key': 10,
#      'id': 'xYKf70HTidE'},
#     {'date': '2021-01-06',
#      'source_type': 'customer_091',
#      'age_group': '18-34',
#      'amount': 9882,
#      'source': 'x_savings',
#      'target': 'competitor_4',
#      'key': 11,
#      'id': 'fwOtOFvq0GT'},
#     {'date': '2021-01-13',
#      'source_type': 'customer_094',
#      'age_group': '35-50',
#      'amount': 1688,
#      'source': 'x_savings',
#      'target': 'competitor_4',
#      'key': 12,
#      'id': 'X_vioMFPdVo'},
#     {'date': '2021-01-10',
#      'source_type': 'customer_099',
#      'age_group': '51-64',
#      'amount': 6168,
#      'source': 'x_savings',
#      'target': 'competitor_4',
#      'key': 13,
#      'id': 'i3bgkjbzceR'},
#     {'date': '2021-01-10',
#      'source_type': 'customer_100',
#      'age_group': '51-64',
#      'amount': 9472,
#      'source': 'x_savings',
#      'target': 'competitor_4',
#      'key': 14,
#      'id': 'eDdrZYEszVx'},
#     {'date': '2021-01-07',
#      'source_type': 'customer_104',
#      'age_group': '51-64',
#      'amount': 1128,
#      'source': 'x_savings',
#      'target': 'competitor_4',
#      'key': 15,
#      'id': 'GaTXQd5PKQt'},
#     {'date': '2021-01-08',
#      'source_type': 'customer_110',
#      'age_group': '65+',
#      'amount': 812,
#      'source': 'x_savings',
#      'target': 'competitor_4',
#      'key': 16,
#      'id': 'rN4BQnH80mF'},
#     {'date': '2021-01-06',
#      'source_type': 'customer_113',
#      'age_group': '51-64',
#      'amount': 9263,
#      'source': 'x_savings',
#      'target': 'competitor_4',
#      'key': 17,
#      'id': '7qJ7QnKc0Xy'},
#     {'date': '2020-08-06',
#      'source_type': 'customer_128',
#      'age_group': '65+',
#      'amount': 1408,
#      'source': 'x_savings',
#      'target': 'competitor_4',
#      'key': 18,
#      'id': 'ZWjlCr59sgl'},
#     {'date': '2020-07-28',
#      'source_type': 'customer_134',
#      'age_group': '51-64',
#      'amount': 3798,
#      'source': 'x_savings',
#      'target': 'competitor_4',
#      'key': 19,
#      'id': '76BX1lc63zc'},
#     {'date': '2020-11-06',
#      'source_type': 'customer_125',
#      'age_group': '51-64',
#      'amount': 3819,
#      'source': 'x_savings',
#      'target': 'competitor_2',
#      'key': 0,
#      'id': 'V5wKD27euNz'},
#     {'date': '2020-07-26',
#      'source_type': 'customer_130',
#      'age_group': '65+',
#      'amount': 3361,
#      'source': 'x_savings',
#      'target': 'competitor_2',
#      'key': 1,
#      'id': 'o0psZDA9N3q'},
#     {'date': '2020-08-15',
#      'source_type': 'customer_126',
#      'age_group': '65+',
#      'amount': 1607,
#      'source': 'x_savings',
#      'target': 'competitor_3',
#      'key': 0,
#      'id': 'haoAWdZusa3'},
#     {'date': '2020-06-13',
#      'source_type': 'customer_132',
#      'age_group': '18-34',
#      'amount': 2789,
#      'source': 'x_savings',
#      'target': 'competitor_3',
#      'key': 1,
#      'id': 'mBsgnFCb_pl'},
#     {'date': '2020-06-12',
#      'source_type': 'customer_127',
#      'age_group': '51-64',
#      'amount': 4507,
#      'source': 'x_savings',
#      'target': 'competitor_1',
#      'key': 0,
#      'id': '1gufP-hxAtj'},
#     {'date': '2020-12-23',
#      'source_type': 'customer_129',
#      'age_group': '65+',
#      'amount': 1500,
#      'source': 'x_savings',
#      'target': 'competitor_1',
#      'key': 1,
#      'id': '-gTIwF4nW_N'},
#     {'date': '2020-06-08',
#      'source_type': 'customer_133',
#      'age_group': '18-34',
#      'amount': 4092,
#      'source': 'x_savings',
#      'target': 'competitor_1',
#      'key': 2,
#      'id': 'S9Q4bswmHdB'},
#     {'date': '2020-08-04',
#      'source_type': 'customer_131',
#      'age_group': '51-64',
#      'amount': 1402,
#      'source': 'x_savings',
#      'target': 'competitor_5',
#      'key': 0,
#      'id': 'ykTpv1KlXeY'},
#     {'date': '2020-06-09',
#      'source_type': 'customer_052',
#      'age_group': '35-50',
#      'amount': 4949,
#      'source': 'competitor_4',
#      'target': 'x_savings',
#      'key': 0,
# ...
#      'id': '7WIFya0NcrA'},
#     {'date': '2020-06-25',
#      'source_type': 'customer_099',
#      'age_group': '51-64',
#      'amount': 6168,
#      'source': 'competitor_2',
#      'target': 'x_savings',
#      'key': 8,
#      'id': 'YeIm8IEQOLd'},
#     {'date': '2020-06-20',
#      'source_type': 'customer_106',
#      'age_group': '65+',
#      'amount': 8793,
#      'source': 'competitor_2',
#      'target': 'x_savings',
#      'key': 9,
#      'id': 'jgBbHst_W6V'},
#     {'date': '2020-07-04',
#      'source_type': 'customer_187',
#      'age_group': '51-64',
#      'amount': 1004,
#      'source': 'competitor_2',
#      'target': 'x_savings',
#      'key': 10,
#      'id': 'bd5X-tG7ETX'},
#     {'date': '2020-10-28',
#      'source_type': 'customer_188',
#      'age_group': '51-64',
#      'amount': 3561,
#      'source': 'competitor_2',
#      'target': 'x_savings',
#      'key': 11,
#      'id': 'uGAbiS7g2CU'},
#     {'date': '2020-09-24',
#      'source_type': 'customer_189',
#      'age_group': '51-64',
#      'amount': 1994,
#      'source': 'competitor_2',
#      'target': 'x_savings',
#      'key': 12,
#      'id': 'RKjoh1O_fEQ'},
#     {'date': '2020-12-18',
#      'source_type': 'customer_192',
#      'age_group': '51-64',
#      'amount': 2470,
#      'source': 'competitor_2',
#      'target': 'x_savings',
#      'key': 13,
#      'id': 'O8-df6u0owm'},
#     {'date': '2020-11-09',
#      'source_type': 'customer_184',
#      'age_group': '18-34',
#      'amount': 1031,
#      'source': 'competitor_2',
#      'target': 'x_insurance',
#      'key': 0,
#      'id': 'YySOTCZkGc_'},
#     {'date': '2020-08-08',
#      'source_type': 'customer_185',
#      'age_group': '35-50',
#      'amount': 4487,
#      'source': 'competitor_2',
#      'target': 'x_insurance',
#      'key': 1,
#      'id': '-8KAAN2-ptk'},
#     {'date': '2020-12-29',
#      'source_type': 'customer_186',
#      'age_group': '51-64',
#      'amount': 4518,
#      'source': 'competitor_2',
#      'target': 'x_insurance',
#      'key': 2,
#      'id': 'Z2LIt0IYpMk'},
#     {'date': '2020-07-23',
#      'source_type': 'customer_193',
#      'age_group': '65+',
#      'amount': 1595,
#      'source': 'competitor_2',
#      'target': 'x_insurance',
#      'key': 3,
#      'id': '6HPznz4wO_N'},
#     {'date': '2020-07-08',
#      'source_type': 'customer_190',
#      'age_group': '35-50',
#      'amount': 2675,
#      'source': 'competitor_2',
#      'target': 'x_investments',
#      'key': 0,
#      'id': 'Q-fWHxgwKnL'},
#     {'date': '2020-08-16',
#      'source_type': 'customer_191',
#      'age_group': '18-34',
#      'amount': 4267,
#      'source': 'competitor_2',
#      'target': 'x_investments',
#      'key': 1,
#      'id': 'OaIfzFAls_m'},
#     {'date': '2020-06-13',
#      'source_type': 'customer_055',
#      'age_group': '35-50',
#      'amount': 3164,
#      'source': 'competitor_1',
#      'target': 'x_savings',
#      'key': 0,
#      'id': 'HjZi30ytL97'},
#     {'date': '2020-06-19',
#      'source_type': 'customer_064',
#      'age_group': '65+',
#      'amount': 661,
#      'source': 'competitor_1',
#      'target': 'x_savings',
#      'key': 1,
#      'id': 'PTbRBBV2mqg'},
#     {'date': '2020-06-02',
#      'source_type': 'customer_070',
#      'age_group': '35-50',
#      'amount': 9423,
#      'source': 'competitor_1',
#      'target': 'x_savings',
#      'key': 2,
#      'id': 'htsjs6KG5kw'},
#     {'date': '2020-06-09',
#      'source_type': 'customer_075',
#      'age_group': '51-64',
#      'amount': 5185,
#      'source': 'competitor_1',
#      'target': 'x_savings',
#      'key': 3,
#      'id': 'ehFJO9gV3ZF'},
#     {'date': '2020-06-22',
#      'source_type': 'customer_077',
#      'age_group': '18-34',
#      'amount': 2014,
#      'source': 'competitor_1',
#      'target': 'x_savings',
#      'key': 4,
#      'id': 'o2o_uxoMTjp'},
#     {'date': '2020-06-04',
#      'source_type': 'customer_079',
#      'age_group': '18-34',
#      'amount': 7587,
#      'source': 'competitor_1',
#      'target': 'x_savings',
#      'key': 5,
#      'id': 'kgjN3QT-C3n'},
#     {'date': '2020-06-30',
#      'source_type': 'customer_092',
#      'age_group': '51-64',
#      'amount': 5559,
#      'source': 'competitor_1',
#      'target': 'x_savings',
#      'key': 6,
#      'id': 'LqCJ7v4o9vS'},
#     {'date': '2020-06-20',
#      'source_type': 'customer_102',
#      'age_group': '65+',
#      'amount': 8767,
#      'source': 'competitor_1',
#      'target': 'x_savings',
#      'key': 7,
#      'id': 'tFYY-dr4GGF'},
#     {'date': '2020-06-01',
#      'source_type': 'customer_107',
#      'age_group': '65+',
#      'amount': 8564,
#      'source': 'competitor_1',
#      'target': 'x_savings',
#      'key': 8,
#      'id': 'amJO7qth_mP'},
#     {'date': '2020-06-02',
#      'source_type': 'customer_108',
#      'age_group': '65+',
#      'amount': 6738,
#      'source': 'competitor_1',
#      'target': 'x_savings',
#      'key': 9,
#      'id': 'OhinU6NrT7J'},
#     {'date': '2020-06-24',
#      'source_type': 'customer_110',
#      'age_group': '65+',
#      'amount': 812,
#      'source': 'competitor_1',
#      'target': 'x_savings',
#      'key': 10,
#      'id': 'Z8EJUQ4UbwJ'},
#     {'date': '2020-06-15',
#      'source_type': 'customer_175',
#      'age_group': '51-64',
#      'amount': 1870,
#      'source': 'competitor_1',
#      'target': 'x_savings',
#      'key': 11,
#      'id': 'ojbNljE74I0'},
#     {'date': '2020-08-11',
#      'source_type': 'customer_178',
#      'age_group': '65+',
#      'amount': 3557,
#      'source': 'competitor_1',
#      'target': 'x_savings',
#      'key': 12,
#      'id': 'uecH5B3GIhy'},
#     {'date': '2020-08-03',
#      'source_type': 'customer_179',
#      'age_group': '18-34',
#      'amount': 2890,
#      'source': 'competitor_1',
#      'target': 'x_savings',
#      'key': 13,
#      'id': 'IyLGuJPszjh'},
#     {'date': '2020-12-03',
#      'source_type': 'customer_183',
#      'age_group': '51-64',
#      'amount': 2746,
#      'source': 'competitor_1',
#      'target': 'x_savings',
#      'key': 14,
#      'id': 'J8Kl92E9BBk'},
#     {'date': '2020-11-26',
#      'source_type': 'customer_174',
#      'age_group': '18-34',
#      'amount': 4629,
#      'source': 'competitor_1',
#      'target': 'x_investments',
#      'key': 0,
#      'id': '_octKTAbRvc'},
#     {'date': '2020-07-11',
#      'source_type': 'customer_176',
#      'age_group': '51-64',
#      'amount': 3135,
#      'source': 'competitor_1',
#      'target': 'x_investments',
#      'key': 1,
#      'id': 'fKNRWWP7GiG'},
#     {'date': '2020-09-03',
#      'source_type': 'customer_177',
#      'age_group': '51-64',
#      'amount': 3822,
#      'source': 'competitor_1',
#      'target': 'x_investments',
#      'key': 2,
#      'id': 'iEDEYIjAvjk'},
#     {'date': '2020-10-30',
#      'source_type': 'customer_180',
#      'age_group': '51-64',
#      'amount': 4610,
#      'source': 'competitor_1',
#      'target': 'x_investments',
#      'key': 3,
#      'id': 'blcKztOHOcl'},
#     {'date': '2020-07-09',
#      'source_type': 'customer_181',
#      'age_group': '35-50',
#      'amount': 4401,
#      'source': 'competitor_1',
#      'target': 'x_insurance',
#      'key': 0,
#      'id': 'ej01ygm5Kek'},
#     {'date': '2020-12-19',
#      'source_type': 'customer_182',
#      'age_group': '51-64',
#      'amount': 2437,
#      'source': 'competitor_1',
#      'target': 'x_insurance',
#      'key': 1,
#      'id': 'fT_sZSGnOiL'},
#     {'date': '2020-06-27',
#      'source_type': 'customer_056',
#      'age_group': '18-34',
#      'amount': 3680,
#      'source': 'competitor_5',
#      'target': 'x_savings',
#      'key': 0,
#      'id': 'l6FbXwXyVRc'},
#     {'date': '2020-06-02',
#      'source_type': 'customer_063',
#      'age_group': '65+',
#      'amount': 1192,
#      'source': 'competitor_5',
#      'target': 'x_savings',
#      'key': 1,
#      'id': 'mKKCvibTZFY'},
#     {'date': '2020-06-20',
#      'source_type': 'customer_072',
#      'age_group': '18-34',
#      'amount': 9835,
#      'source': 'competitor_5',
#      'target': 'x_savings',
#      'key': 2,
#      'id': 'WCdJWOZPU1c'},
#     {'date': '2020-06-20',
#      'source_type': 'customer_078',
#      'age_group': '35-50',
#      'amount': 8852,
#      'source': 'competitor_5',
#      'target': 'x_savings',
#      'key': 3,
#      'id': 'qFu4NrwEw2H'},
#     {'date': '2020-06-02',
#      'source_type': 'customer_087',
#      'age_group': '18-34',
#      'amount': 9296,
#      'source': 'competitor_5',
#      'target': 'x_savings',
#      'key': 4,
#      'id': '_Wl2Xfyfw5S'},
#     {'date': '2020-06-06',
#      'source_type': 'customer_088',
#      'age_group': '18-34',
#      'amount': 7890,
#      'source': 'competitor_5',
#      'target': 'x_savings',
#      'key': 5,
#      'id': 'qARMPXVqgm8'},
#     {'date': '2020-06-07',
#      'source_type': 'customer_091',
#      'age_group': '18-34',
#      'amount': 9882,
#      'source': 'competitor_5',
#      'target': 'x_savings',
#      'key': 6,
#      'id': 'yzglYxEFZnj'},
#     {'date': '2020-06-04',
#      'source_type': 'customer_095',
#      'age_group': '18-34',
#      'amount': 4112,
#      'source': 'competitor_5',
#      'target': 'x_savings',
#      'key': 7,
#      'id': 'e0BLwpt7yq8'},
#     {'date': '2020-06-26',
#      'source_type': 'customer_101',
#      'age_group': '65+',
#      'amount': 7697,
#      'source': 'competitor_5',
#      'target': 'x_savings',
#      'key': 8,
#      'id': 'D7se3w86bK2'},
#     {'date': '2020-09-23',
#      'source_type': 'customer_217',
#      'age_group': '51-64',
#      'amount': 3596,
#      'source': 'competitor_5',
#      'target': 'x_savings',
#      'key': 9,
#      'id': 'i84uBJy9_vM'},
#     {'date': '2020-10-11',
#      'source_type': 'customer_220',
#      'age_group': '51-64',
#      'amount': 4597,
#      'source': 'competitor_5',
#      'target': 'x_savings',
#      'key': 10,
#      'id': '1nV4pTQiWtJ'},
#     {'date': '2020-09-25',
#      'source_type': 'customer_222',
#      'age_group': '18-34',
#      'amount': 1425,
#      'source': 'competitor_5',
#      'target': 'x_savings',
#      'key': 11,
#      'id': 'qSl7niLcVm_'},
#     {'date': '2020-09-26',
#      'source_type': 'customer_214',
#      'age_group': '35-50',
#      'amount': 1953,
#      'source': 'competitor_5',
#      'target': 'x_insurance',
#      'key': 0,
#      'id': 'spF8UW1tHLP'},
#     {'date': '2020-06-29',
#      'source_type': 'customer_216',
#      'age_group': '65+',
#      'amount': 1380,
#      'source': 'competitor_5',
#      'target': 'x_insurance',
#      'key': 1,
#      'id': '-qN8v75W6my'},
#     {'date': '2020-09-25',
#      'source_type': 'customer_218',
#      'age_group': '65+',
#      'amount': 2793,
#      'source': 'competitor_5',
#      'target': 'x_insurance',
#      'key': 2,
#      'id': 'q-GnRUVft6v'},
#     {'date': '2020-08-13',
#      'source_type': 'customer_219',
#      'age_group': '35-50',
#      'amount': 1942,
#      'source': 'competitor_5',
#      'target': 'x_insurance',
#      'key': 3,
#      'id': 'wn-bHfS4_9W'},
#     {'date': '2020-06-18',
#      'source_type': 'customer_223',
#      'age_group': '51-64',
#      'amount': 3725,
#      'source': 'competitor_5',
#      'target': 'x_insurance',
#      'key': 4,
#      'id': 'xGEmlCw0-cM'},
#     {'date': '2020-12-16',
#      'source_type': 'customer_215',
#      'age_group': '51-64',
#      'amount': 4229,
#      'source': 'competitor_5',
#      'target': 'x_investments',
#      'key': 0,
#      'id': 'dke-T2-CbIf'},
#     {'date': '2020-08-10',
#      'source_type': 'customer_221',
#      'age_group': '18-34',
#      'amount': 4335,
#      'source': 'competitor_5',
#      'target': 'x_investments',
#      'key': 1,
#      'id': 'cLfgK7jSfQo'},
#     {'date': '2020-06-03',
#      'source_type': 'customer_059',
#      'age_group': '18-34',
#      'amount': 6075,
#      'source': 'competitor_3',
#      'target': 'x_savings',
#      'key': 0,
#      'id': 'AxJTfYYmL2Z'},
#     {'date': '2020-06-06',
#      'source_type': 'customer_068',
#      'age_group': '51-64',
#      'amount': 696,
#      'source': 'competitor_3',
#      'target': 'x_savings',
#      'key': 1,
#      'id': 'OfmtDnmXAao'},
#     {'date': '2020-06-20',
#      'source_type': 'customer_084',
#      'age_group': '65+',
#      'amount': 5097,
#      'source': 'competitor_3',
#      'target': 'x_savings',
#      'key': 2,
#      'id': 'DRHxcxR8bZL'},
#     {'date': '2020-06-16',
#      'source_type': 'customer_086',
#      'age_group': '51-64',
#      'amount': 800,
#      'source': 'competitor_3',
#      'target': 'x_savings',
#      'key': 3,
#      'id': 'Z_hD0xviMMp'},
#     {'date': '2020-06-29',
#      'source_type': 'customer_093',
#      'age_group': '51-64',
#      'amount': 7499,
#      'source': 'competitor_3',
#      'target': 'x_savings',
#      'key': 4,
#      'id': '5wNNT05eauf'},
#     {'date': '2020-06-07',
#      'source_type': 'customer_100',
#      'age_group': '51-64',
#      'amount': 9472,
#      'source': 'competitor_3',
#      'target': 'x_savings',
#      'key': 5,
#      'id': '5diln0PHlg-'},
#     {'date': '2020-07-28',
#      'source_type': 'customer_195',
#      'age_group': '51-64',
#      'amount': 3271,
#      'source': 'competitor_3',
#      'target': 'x_savings',
#      'key': 6,
#      'id': '-4C8L7qH2eM'},
#     {'date': '2020-09-16',
#      'source_type': 'customer_197',
#      'age_group': '65+',
#      'amount': 4252,
#      'source': 'competitor_3',
#      'target': 'x_savings',
#      'key': 7,
#      'id': 'mcBDI-K3mPs'},
#     {'date': '2020-07-09',
#      'source_type': 'customer_198',
#      'age_group': '51-64',
#      'amount': 1086,
#      'source': 'competitor_3',
#      'target': 'x_savings',
#      'key': 8,
#      'id': '4jJCgJVDs7D'},
#     {'date': '2020-08-18',
#      'source_type': 'customer_199',
#      'age_group': '65+',
#      'amount': 3913,
#      'source': 'competitor_3',
#      'target': 'x_savings',
#      'key': 9,
#      'id': 'xeuOGAocy61'},
#     {'date': '2020-08-24',
#      'source_type': 'customer_201',
#      'age_group': '51-64',
#      'amount': 3405,
#      'source': 'competitor_3',
#      'target': 'x_savings',
#      'key': 10,
#      'id': 'CkKbQ5sK036'},
#     {'date': '2020-10-22',
#      'source_type': 'customer_202',
#      'age_group': '51-64',
#      'amount': 2272,
#      'source': 'competitor_3',
#      'target': 'x_savings',
#      'key': 11,
#      'id': 'vnB4kxbA2iv'},
#     {'date': '2020-09-15',
#      'source_type': 'customer_203',
#      'age_group': '35-50',
#      'amount': 1306,
#      'source': 'competitor_3',
#      'target': 'x_savings',
#      'key': 12,
#      'id': 'n-YrFoQSHAF'},
#     {'date': '2020-07-14',
#      'source_type': 'customer_194',
#      'age_group': '65+',
#      'amount': 1489,
#      'source': 'competitor_3',
#      'target': 'x_investments',
#      'key': 0,
#      'id': 'PLR9g-AkIRN'},
#     {'date': '2020-10-22',
#      'source_type': 'customer_196',
#      'age_group': '65+',
#      'amount': 4527,
#      'source': 'competitor_3',
#      'target': 'x_investments',
#      'key': 1,
#      'id': '4YWKEL2LjxO'},
#     {'date': '2020-06-30',
#      'source_type': 'customer_200',
#      'age_group': '65+',
#      'amount': 3367,
#      'source': 'competitor_3',
#      'target': 'x_insurance',
#      'key': 0,
#      'id': '4phKy33QH4z'}],
#    'metadata': {'fields': {'nodes': [{'name': 'id',
#        'format': '',
#        'type': 'string',
#        'analyzerType': 'STRING'},
#       {'name': 'value',
#        'format': '',
#        'type': 'string',
#        'analyzerType': 'STRING'},
#       {'name': 'name',
#        'format': '',
#        'type': 'string',
#        'analyzerType': 'STRING'}],
#      'edges': [{'name': 'date',
#        'format': 'YYYY-M-D',
#        'type': 'date',
#        'analyzerType': 'DATE'},
#       {'name': 'source_type',
#        'format': '',
#        'type': 'string',
#        'analyzerType': 'STRING'},
#       {'name': 'age_group',
#        'format': '',
#        'type': 'string',
#        'analyzerType': 'STRING'},
#       {'name': 'amount',
#        'format': '',
#        'type': 'integer',
#        'analyzerType': 'INT'},
#       {'name': 'source',
#        'format': '',
#        'type': 'string',
#        'analyzerType': 'STRING'},
#       {'name': 'target',
#        'format': '',
#        'type': 'string',
#        'analyzerType': 'STRING'},
#       {'name': 'key',
#        'format': '',
#        'type': 'integer',
#        'analyzerType': 'INT'}]},
#     'key': 'bZ5v6Zz0W',
#     'groupEdges': {'toggle': True, 'availability': True, 'type': 'all'}}}],
#  'style': {'layout': {'type': 'concentric',
#    'minNodeSpacing': 50,
#    'sortBy': 'degree',
#    'preventOverlap': True,
#    'workerEnabled': True},
#   'nodeStyle': {'color': {'id': 'fixed', 'value': '#66c2a5'},
#    'size': {'id': 'fixed', 'value': 20}},
#   'edgeStyle': {'width': {'id': 'fixed', 'value': 1}, 'label': 'none'}}}

# %%
style = { 'layout': { 'type': 'radial' } }
# motif.set_style(style, True)
motif.set_style(style)

motif

# %%
# motif.add_graph(nx_graph=g1)
# motif.add_nx_graph(g2)

style = { 'layout': { 'type': 'radial' } }
# motif.add_graph(nx_graph=g1, title='BAR', style=style)
motif.add_graph(csv_path='edgelist.csv', title='BAR')
# motif.add_graph(json_path='test.json', title='BAR')

motif.plot()

# %%
motif
